# %%
name=input("Enter your name?")
# Out:
# Enter your name? 100

# %%
marks=int(input("Enter the marks ?"))
# Out:
# Enter the marks ? 100

# %%
print("Entered marks are :", marks)
# Out:
# Entered marks are : 100

# %%
if 100>=marks>=85:
    print("Exelent, ",name," You have A pass")
elif marks>75:
    print("Great, You B pass")
elif marks>65:
    print("Good, You have C pass")
elif marks>65:
    print("Fair, You have D pass")
else:
    print("Sorry, You have failed, Try again")
# Out:
# Exelent,  100  You have A pass
