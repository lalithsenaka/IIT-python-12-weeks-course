# %% [markdown]
# # Python week 01

# %% [markdown]
# ## How to download python

# %% [markdown]
# www.python.org >> download>

# %% [markdown]
# ![image.png](attachment:12fb3310-5ba9-4ccf-abaa-14194c659326.png)

# %% [markdown]
# Install the exe file by db clicking

# %% [markdown]
# ![image.png](attachment:cca7848a-2175-40ab-8622-a3a6e775330e.png)

# %% [markdown]
# veryfy the installation>> command line>>python --version

# %% [markdown]
# ![image.png](attachment:c57cc058-594e-43e3-b4a4-6cb3609acb9a.png)

# %% [markdown]
# ### how to run python via comman prompt

# %% [markdown]
# command promt>>python

# %% [markdown]
# ![image.png](attachment:96dcf728-b50a-4ca4-98de-d79f83f9bf61.png)

# %% [markdown]
# ### do some activities>> addition 5+10

# %% [markdown]
# ![image.png](attachment:4cc0c968-39a8-4112-a9ee-badebfcee6ff.png)

# %% [markdown]
# type exit to leave from comman promt

# %% [markdown]
# ![image.png](attachment:3036f9a9-fcda-4d34-9464-5a13a886da65.png)
